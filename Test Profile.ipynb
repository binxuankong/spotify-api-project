# %%
import pandas as pd

user_id = 12120382831
top_artists = pd.read_csv('data/top_artists.csv')
top_tracks = pd.read_csv('data/top_tracks.csv')

# %%
top_artists.head()
# Out:
#        user_id  rank         artist  \
# 0  12120382831     1       Jay Chou
# 1  12120382831     2       Kid Cudi
# 2  12120382831     3           Joji
# 3  12120382831     4  Calvin Harris
# 4  12120382831     5    Frank Ocean
#
#                                               genres  \
# 0         c-pop; mandopop; taiwan pop; zhongguo feng
# 1                         ohio hip hop; pop rap; rap
# 2                         alternative r&b; viral pop
# 3  dance pop; edm; electro house; house; pop; pop...
# 4  alternative r&b; hip hop; lgbtq+ hip hop; neo ...
#
#                                           artist_url timeframe
# 0  https://open.spotify.com/artist/2elBjNSdBE2Y3f...     Short
# 1  https://open.spotify.com/artist/0fA0VVWsXO9YnA...     Short
# 2  https://open.spotify.com/artist/3MZsBdqDrRTJih...     Short
# 3  https://open.spotify.com/artist/7CajNmpbOovFoO...     Short
# 4  https://open.spotify.com/artist/2h93pZq0e7k5yf...     Short

# %%
top_tracks.head()
# Out:
#        user_id  rank                           track               artists  \
# 0  12120382831     1                              安靜              Jay Chou
# 1  12120382831     2       With You (Jai Wolf Remix)  Dirty South; FMLYBND
# 2  12120382831     1                              安靜              Jay Chou
# 3  12120382831     2                         With Me                Sum 41
# 4  12120382831     3  Wake Me up When September Ends             Green Day
#
#                     album release_date  \
# 0                     范特西   2001-09-14
# 1  With You (The Remixes)   2015-04-28
# 2                     范特西   2001-09-14
# 3         Underclass Hero   2007-01-01
# 4          American Idiot   2004-09-21
#
#                                            track_url timeframe
# 0  https://open.spotify.com/track/4FOydQ5IdqmdeBg...     Short
# 1  https://open.spotify.com/track/5H2cgEPEJxA72Bq...     Short
# 2  https://open.spotify.com/track/4FOydQ5IdqmdeBg...    Medium
# 3  https://open.spotify.com/track/1OTvWduKQV0MQd2...    Medium
# 4  https://open.spotify.com/track/3ZffCQKLFLUvYM5...    Medium

# %%
top_artists = top_artists.loc[top_artists['user_id'] == user_id]
top_artists.head()
# Out:
#        user_id  rank         artist  \
# 0  12120382831     1       Jay Chou
# 1  12120382831     2       Kid Cudi
# 2  12120382831     3           Joji
# 3  12120382831     4  Calvin Harris
# 4  12120382831     5    Frank Ocean
#
#                                               genres  \
# 0         c-pop; mandopop; taiwan pop; zhongguo feng
# 1                         ohio hip hop; pop rap; rap
# 2                         alternative r&b; viral pop
# 3  dance pop; edm; electro house; house; pop; pop...
# 4  alternative r&b; hip hop; lgbtq+ hip hop; neo ...
#
#                                           artist_url timeframe
# 0  https://open.spotify.com/artist/2elBjNSdBE2Y3f...     Short
# 1  https://open.spotify.com/artist/0fA0VVWsXO9YnA...     Short
# 2  https://open.spotify.com/artist/3MZsBdqDrRTJih...     Short
# 3  https://open.spotify.com/artist/7CajNmpbOovFoO...     Short
# 4  https://open.spotify.com/artist/2h93pZq0e7k5yf...     Short

# %%
top_tracks = top_tracks.loc[top_tracks['user_id'] == user_id]
top_tracks.head()
# Out:
#        user_id  rank                           track               artists  \
# 0  12120382831     1                              安靜              Jay Chou
# 1  12120382831     2       With You (Jai Wolf Remix)  Dirty South; FMLYBND
# 2  12120382831     1                              安靜              Jay Chou
# 3  12120382831     2                         With Me                Sum 41
# 4  12120382831     3  Wake Me up When September Ends             Green Day
#
#                     album release_date  \
# 0                     范特西   2001-09-14
# 1  With You (The Remixes)   2015-04-28
# 2                     范特西   2001-09-14
# 3         Underclass Hero   2007-01-01
# 4          American Idiot   2004-09-21
#
#                                            track_url timeframe
# 0  https://open.spotify.com/track/4FOydQ5IdqmdeBg...     Short
# 1  https://open.spotify.com/track/5H2cgEPEJxA72Bq...     Short
# 2  https://open.spotify.com/track/4FOydQ5IdqmdeBg...    Medium
# 3  https://open.spotify.com/track/1OTvWduKQV0MQd2...    Medium
# 4  https://open.spotify.com/track/3ZffCQKLFLUvYM5...    Medium

# %%
def top_to_dict(top_df):
    top_dict = {}
    top_dict['Short'] = top_df.loc[top_df['timeframe'] == 'Short'].to_dict('records')
    top_dict['Medium'] = top_df.loc[top_df['timeframe'] == 'Medium'].to_dict('records')
    top_dict['Long'] = top_df.loc[top_df['timeframe'] == 'Long'].to_dict('records')
    return top_dict

# %%
top_to_dict(top_tracks)
# Out:
# {'Short': [{'user_id': 12120382831,
#    'rank': 1,
#    'track': '安靜',
#    'artists': 'Jay Chou',
#    'album': '范特西',
#    'release_date': '2001-09-14',
#    'track_url': 'https://open.spotify.com/track/4FOydQ5IdqmdeBgG9vFbPg',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 2,
#    'track': 'With You (Jai Wolf Remix)',
#    'artists': 'Dirty South; FMLYBND',
#    'album': 'With You (The Remixes)',
#    'release_date': '2015-04-28',
#    'track_url': 'https://open.spotify.com/track/5H2cgEPEJxA72Bqb4cLvrj',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 3,
#    'track': 'Saw You in a Dream',
#    'artists': 'The Japanese House',
#    'album': 'Saw You in a Dream',
#    'release_date': '2017-06-30',
#    'track_url': 'https://open.spotify.com/track/7dujOm8FJcepmVBQjqdswN',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 4,
#    'track': 'Nikes',
#    'artists': 'Frank Ocean',
#    'album': 'Blonde',
#    'release_date': '2016-08-20',
#    'track_url': 'https://open.spotify.com/track/19YKaevk2bce4odJkP5L22',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 5,
#    'track': '算什麼男人',
#    'artists': 'Jay Chou',
#    'album': '哎呦 不錯哦',
#    'release_date': '2014-12-26',
#    'track_url': 'https://open.spotify.com/track/7vs3JM90lKhp11av83WA5j',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 6,
#    'track': '千里之外',
#    'artists': 'Jay Chou',
#    'album': '依然范特西',
#    'release_date': '2006-09-05',
#    'track_url': 'https://open.spotify.com/track/02K5L2D21TVIINipDIPEfA',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 7,
#    'track': '明明就',
#    'artists': 'Jay Chou',
#    'album': '十二新作',
#    'release_date': '2012-12-28',
#    'track_url': 'https://open.spotify.com/track/04x6DpeFQ72efXsD0DmWPQ',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 8,
#    'track': 'How to Disappear Completely',
#    'artists': 'Radiohead',
#    'album': 'Kid A',
#    'release_date': '2000-10-02',
#    'track_url': 'https://open.spotify.com/track/2rtGaCAeYtmcIvuZsvgTf6',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 9,
#    'track': '七里香',
#    'artists': 'Jay Chou',
#    'album': '七里香',
#    'release_date': '2004-08-03',
#    'track_url': 'https://open.spotify.com/track/3kwqNLXvsjSrIXbVsRBj8q',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 10,
#    'track': 'Disarm You (feat. Ilsey)',
#    'artists': 'Kaskade; Ilsey',
#    'album': 'Automatic',
#    'release_date': '2015-09-25',
#    'track_url': 'https://open.spotify.com/track/3xQjivjUZ4KnUslduTEYKC',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 11,
#    'track': '青花瓷',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/479lquEL4Mzh3tQLtnHVfL',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 12,
#    'track': 'Harvest Moon',
#    'artists': 'Handsome Ghost',
#    'album': 'Harvest Moon',
#    'release_date': '2018-01-05',
#    'track_url': 'https://open.spotify.com/track/4C9rhLT37Gv6VMVtFCb7O1',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 13,
#    'track': '彩虹',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/4KJx4IOvCU2isprmXio9Xk',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 14,
#    'track': '黑色毛衣',
#    'artists': 'Jay Chou',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/4MNuUPVgAALVneM0kughvi',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 15,
#    'track': 'Fall for You (Acoustic)',
#    'artists': 'Secondhand Serenade',
#    'album': 'A Naked Twist in My Story',
#    'release_date': '2012',
#    'track_url': 'https://open.spotify.com/track/5V7mTIcXVU9k2JNu0mE6vy',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 16,
#    'track': 'In Flames',
#    'artists': 'Dabin; Lexi Norton',
#    'album': 'Pyres',
#    'release_date': '2018-03-30',
#    'track_url': 'https://open.spotify.com/track/5W8DSMQe7cbTtKTHY0yEnP',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 17,
#    'track': 'Cold Water (feat. Justin Bieber & MØ)',
#    'artists': 'Major Lazer; Justin Bieber; MØ',
#    'album': 'Cold Water (feat. Justin Bieber & MØ)',
#    'release_date': '2016-07-22',
#    'track_url': 'https://open.spotify.com/track/5x9uAWpQ0qj8V61xckw6TV',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 18,
#    'track': 'Tears in Heaven - Acoustic; Live at MTV Unplugged, Bray Film Studios, Windsor, England, UK, 1/16/1992; 2013 Remaster',
#    'artists': 'Eric Clapton',
#    'album': 'Unplugged (Deluxe Edition)',
#    'release_date': '1992-08-25',
#    'track_url': 'https://open.spotify.com/track/612VcBshQcy4mpB2utGc3H',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 19,
#    'track': '最長的電影',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/6C9w3NKP7yKqGLBP09iEL4',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 20,
#    'track': 'Everybody Hurts',
#    'artists': 'R.E.M.',
#    'album': 'Automatic For The People',
#    'release_date': '1992-10-05',
#    'track_url': 'https://open.spotify.com/track/6PypGyiu0Y2lCDBN1XZEnP',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 21,
#    'track': 'Sweet',
#    'artists': 'Cigarettes After Sex',
#    'album': 'Cigarettes After Sex',
#    'release_date': '2017-06-09',
#    'track_url': 'https://open.spotify.com/track/6ilc4vQcwMPlvAHFfsTGng',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 22,
#    'track': 'Same Drugs',
#    'artists': 'Chance the Rapper',
#    'album': 'Coloring Book',
#    'release_date': '2016-05-27',
#    'track_url': 'https://open.spotify.com/track/6m9qPYXmhge2QhBLfFKnVF',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 23,
#    'track': 'Middle',
#    'artists': 'DJ Snake; Bipolar Sunshine',
#    'album': 'Encore',
#    'release_date': '2016-08-05',
#    'track_url': 'https://open.spotify.com/track/0g5EKLgdKvNlln7TNqBByK',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 24,
#    'track': 'Collard Greens',
#    'artists': 'ScHoolboy Q; Kendrick Lamar',
#    'album': 'Oxymoron (Deluxe)',
#    'release_date': '2014-01-01',
#    'track_url': 'https://open.spotify.com/track/0zO8ctW0UiuOefR87OeJOZ',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 25,
#    'track': 'Ghost Town',
#    'artists': 'Kanye West; PARTYNEXTDOOR',
#    'album': 'ye',
#    'release_date': '2018-06-01',
#    'track_url': 'https://open.spotify.com/track/7vgTNTaEz3CsBZ1N4YQalM',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 26,
#    'track': '退後',
#    'artists': 'Jay Chou',
#    'album': '依然范特西',
#    'release_date': '2006-09-05',
#    'track_url': 'https://open.spotify.com/track/1xYPMWVdl2yqOkQpjWPVbU',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 27,
#    'track': 'Come Down',
#    'artists': 'Anderson .Paak',
#    'album': 'Malibu',
#    'release_date': '2016-01-15',
#    'track_url': 'https://open.spotify.com/track/276zciJ7Fg7Jk6Ta6QuLkp',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 28,
#    'track': "Why'd You Only Call Me When You're High?",
#    'artists': 'Arctic Monkeys',
#    'album': 'AM',
#    'release_date': '2013-09-09',
#    'track_url': 'https://open.spotify.com/track/086myS9r57YsLbJpU0TgK9',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 29,
#    'track': 'Cancer',
#    'artists': 'My Chemical Romance',
#    'album': 'The Black Parade',
#    'release_date': '2006-10-23',
#    'track_url': 'https://open.spotify.com/track/0GgN4MhR5GKn5IcKN0e0rG',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 30,
#    'track': '開不了口',
#    'artists': 'Jay Chou',
#    'album': '范特西',
#    'release_date': '2001-09-14',
#    'track_url': 'https://open.spotify.com/track/0JB2nnrP35zVYnQcYpAnCb',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 31,
#    'track': 'Blessed',
#    'artists': 'Daniel Caesar',
#    'album': 'Freudian',
#    'release_date': '2017-08-25',
#    'track_url': 'https://open.spotify.com/track/0KyzXQhY2yzcb1FYCHkZc2',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 32,
#    'track': 'Let Your Heart Hold Fast',
#    'artists': 'Fort Atlantic',
#    'album': 'Fort Atlantic',
#    'release_date': '2012-05-29',
#    'track_url': 'https://open.spotify.com/track/0poxIvI8mH3TZcGp4T7BWs',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 33,
#    'track': 'Headlights (feat. Ilsey)',
#    'artists': 'Robin Schulz; Ilsey',
#    'album': 'Sugar',
#    'release_date': '2015-09-25',
#    'track_url': 'https://open.spotify.com/track/0tDC3KJPPu5eonGTtCURpq',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 34,
#    'track': 'Overthinking',
#    'artists': 'Acid Ghost',
#    'album': 'I Want to Hide My Face & Die',
#    'release_date': '2015-11-26',
#    'track_url': 'https://open.spotify.com/track/0w2kfnU1PFKxjmZFQ1J1X8',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 35,
#    'track': 'Until You Were Gone',
#    'artists': 'The Chainsmokers; Tritonal; Emily Warren',
#    'album': 'Until You Were Gone',
#    'release_date': '2015-09-18',
#    'track_url': 'https://open.spotify.com/track/12MqM3S0fTvR6X4Jt1Xvn6',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 36,
#    'track': "Don't Let Me Down (feat. Daya) - Illenium Remix",
#    'artists': 'The Chainsmokers; Daya; ILLENIUM',
#    'album': "Don't Let Me Down (Remixes) (feat. Daya)",
#    'release_date': '2016-05-27',
#    'track_url': 'https://open.spotify.com/track/15BlympuVSfZFROojEMY2M',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 37,
#    'track': 'I Miss You',
#    'artists': 'blink-182',
#    'album': 'blink-182',
#    'release_date': '2003-11-01',
#    'track_url': 'https://open.spotify.com/track/1AdYZ6X00nXmO613Y7GJOl',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 38,
#    'track': '給我一首歌的時間',
#    'artists': 'Jay Chou',
#    'album': '魔杰座',
#    'release_date': '2008-11-09',
#    'track_url': 'https://open.spotify.com/track/1KlVJebZrrMSMxcEKOV5w5',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 39,
#    'track': 'Sleepy Eyes',
#    'artists': 'Elohim; Whethan',
#    'album': 'Elohim (Deluxe Edition)',
#    'release_date': '2019-04-26',
#    'track_url': 'https://open.spotify.com/track/1Wvzo4EotLEh4W3OVcQoDO',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 40,
#    'track': 'Japanese Denim',
#    'artists': 'Daniel Caesar',
#    'album': 'Get You - Single',
#    'release_date': '2016-10-21',
#    'track_url': 'https://open.spotify.com/track/1boXOL0ua7N2iCOUVI1p9F',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 41,
#    'track': 'Spectrum',
#    'artists': 'Zedd; Matthew Koma',
#    'album': 'Clarity',
#    'release_date': '2012-01-01',
#    'track_url': 'https://open.spotify.com/track/1dFkD1JfRMzwO6hwUsE8aS',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 42,
#    'track': 'Fantasy - Felix Jaehn Remix',
#    'artists': 'Alina Baraz; Galimatias; Felix Jaehn',
#    'album': 'Ultra Summer 2 (The Best In Deep and Tropical House)',
#    'release_date': '2015-06-29',
#    'track_url': 'https://open.spotify.com/track/203t5YqpCFmIdxj8hIotxo',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 43,
#    'track': 'Miami 82 - Kygo Remix',
#    'artists': 'Syn Cole; Kygo',
#    'album': 'Armada Deep House Selection, Vol. 3 (The Finest Deep House Tunes)',
#    'release_date': '2014-06-06',
#    'track_url': 'https://open.spotify.com/track/2DFT4mdft2yUPs7rX6coSd',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 44,
#    'track': 'Good To Sea',
#    'artists': 'Pinback',
#    'album': 'Autumn of the Seraphs',
#    'release_date': '2007-09-11',
#    'track_url': 'https://open.spotify.com/track/2EH1ZVZx2wPGtQb5V2hNih',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 45,
#    'track': "Don't Don't Do It!",
#    'artists': 'N.E.R.D; Kendrick Lamar; Pharrell Williams',
#    'album': 'NO ONE EVER REALLY DIES',
#    'release_date': '2017-12-15',
#    'track_url': 'https://open.spotify.com/track/2svutFGaCycRmYc1mWbfQh',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 46,
#    'track': 'Horizon',
#    'artists': 'Seven Lions; Tritonal; Kill The Noise; HALIENE',
#    'album': 'Horizon',
#    'release_date': '2018-05-18',
#    'track_url': 'https://open.spotify.com/track/3F1TIgyzrfdU4dF8c4C75U',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 47,
#    'track': 'Mad World (Feat. Michael Andrews)',
#    'artists': 'Gary Jules; Michael Andrews',
#    'album': 'Trading Snakeoil for Wolftickets',
#    'release_date': '2001-01-01',
#    'track_url': 'https://open.spotify.com/track/3JOVTQ5h8HGFnDdp4VT3MP',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 48,
#    'track': 'Love$ick (feat. A$AP Rocky)',
#    'artists': 'Mura Masa; A$AP Rocky',
#    'album': 'Mura Masa',
#    'release_date': '2017-07-14',
#    'track_url': 'https://open.spotify.com/track/3sTN90bIP2cJ1783ctHykO',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 49,
#    'track': 'Beautiful Trip',
#    'artists': 'Kid Cudi',
#    'album': 'Man On The Moon III: The Chosen',
#    'release_date': '2020-12-11',
#    'track_url': 'https://open.spotify.com/track/4IIuCotvqijraSdnVLaFnM',
#    'timeframe': 'Short'},
#   {'user_id': 12120382831,
#    'rank': 50,
#    'track': '珊瑚海',
#    'artists': 'Jay Chou; Lara Liang',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/4JY5s40ymnG18f6wxQtzPw',
#    'timeframe': 'Short'}],
#  'Medium': [{'user_id': 12120382831,
#    'rank': 1,
#    'track': '安靜',
#    'artists': 'Jay Chou',
#    'album': '范特西',
#    'release_date': '2001-09-14',
#    'track_url': 'https://open.spotify.com/track/4FOydQ5IdqmdeBgG9vFbPg',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 2,
#    'track': 'With Me',
#    'artists': 'Sum 41',
#    'album': 'Underclass Hero',
#    'release_date': '2007-01-01',
#    'track_url': 'https://open.spotify.com/track/1OTvWduKQV0MQd2gnGM9He',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 3,
#    'track': 'Wake Me up When September Ends',
#    'artists': 'Green Day',
#    'album': 'American Idiot',
#    'release_date': '2004-09-21',
#    'track_url': 'https://open.spotify.com/track/3ZffCQKLFLUvYM59XKLbVm',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 4,
#    'track': 'Welcome to the Black Parade',
#    'artists': 'My Chemical Romance',
#    'album': 'The Black Parade',
#    'release_date': '2006-10-23',
#    'track_url': 'https://open.spotify.com/track/5wQnmLuC1W7ATsArWACrgW',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 5,
#    'track': '珊瑚海',
#    'artists': 'Jay Chou; Lara Liang',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/4JY5s40ymnG18f6wxQtzPw',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 6,
#    'track': 'Fix You',
#    'artists': 'Coldplay',
#    'album': 'X&Y',
#    'release_date': '2005-06-07',
#    'track_url': 'https://open.spotify.com/track/7LVHVU3tWfcxj5aiPFEW4Q',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 7,
#    'track': 'Always',
#    'artists': 'blink-182',
#    'album': 'Greatest Hits',
#    'release_date': '2005-10-31',
#    'track_url': 'https://open.spotify.com/track/4B7e9sBkcw1iWJ45GaUQWm',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 8,
#    'track': 'The Reason',
#    'artists': 'Hoobastank',
#    'album': 'The Reason (15th Anniversary Deluxe)',
#    'release_date': '2003-12-09',
#    'track_url': 'https://open.spotify.com/track/77loZpT5Y5PRP1S451P9Yz',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 9,
#    'track': '明明就',
#    'artists': 'Jay Chou',
#    'album': '十二新作',
#    'release_date': '2012-12-28',
#    'track_url': 'https://open.spotify.com/track/04x6DpeFQ72efXsD0DmWPQ',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 10,
#    'track': 'How to Save a Life',
#    'artists': 'The Fray',
#    'album': 'How To Save A Life',
#    'release_date': '2005-09-13',
#    'track_url': 'https://open.spotify.com/track/5fVZC9GiM4e8vu99W0Xf6J',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 11,
#    'track': 'I Miss You',
#    'artists': 'blink-182',
#    'album': 'blink-182',
#    'release_date': '2003-11-01',
#    'track_url': 'https://open.spotify.com/track/1AdYZ6X00nXmO613Y7GJOl',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 12,
#    'track': '算什麼男人',
#    'artists': 'Jay Chou',
#    'album': '哎呦 不錯哦',
#    'release_date': '2014-12-26',
#    'track_url': 'https://open.spotify.com/track/7vs3JM90lKhp11av83WA5j',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 13,
#    'track': "I Don't Love You",
#    'artists': 'My Chemical Romance',
#    'album': 'The Black Parade',
#    'release_date': '2006-10-23',
#    'track_url': 'https://open.spotify.com/track/4RAOI1etsgbh5NP3T5R8rN',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 14,
#    'track': 'Your Call',
#    'artists': 'Secondhand Serenade',
#    'album': 'Awake',
#    'release_date': '2007',
#    'track_url': 'https://open.spotify.com/track/7ddJJFmXZ3984IbVEKinp5',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 15,
#    'track': 'Mr. Brightside',
#    'artists': 'The Killers',
#    'album': 'Hot Fuss',
#    'release_date': '2004',
#    'track_url': 'https://open.spotify.com/track/003vvx7Niy0yvhvHt4a68B',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 16,
#    'track': '退後',
#    'artists': 'Jay Chou',
#    'album': '依然范特西',
#    'release_date': '2006-09-05',
#    'track_url': 'https://open.spotify.com/track/1xYPMWVdl2yqOkQpjWPVbU',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 17,
#    'track': '等你下課',
#    'artists': 'Jay Chou; Gary Yang',
#    'album': '等你下課',
#    'release_date': '2018-01-18',
#    'track_url': 'https://open.spotify.com/track/76WthWB0v0KXUHZoAclMVV',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 18,
#    'track': '給我一首歌的時間',
#    'artists': 'Jay Chou',
#    'album': '魔杰座',
#    'release_date': '2008-11-09',
#    'track_url': 'https://open.spotify.com/track/1KlVJebZrrMSMxcEKOV5w5',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 19,
#    'track': '告白氣球',
#    'artists': 'Jay Chou',
#    'album': '周杰倫的床邊故事',
#    'release_date': '2016-06-24',
#    'track_url': 'https://open.spotify.com/track/1ivCIgrYZyE0BvItL4Z8lk',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 20,
#    'track': 'Viva La Vida',
#    'artists': 'Coldplay',
#    'album': 'Viva La Vida or Death and All His Friends',
#    'release_date': '2008-05-26',
#    'track_url': 'https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 21,
#    'track': '青花瓷',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/479lquEL4Mzh3tQLtnHVfL',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 22,
#    'track': 'The Anthem',
#    'artists': 'Good Charlotte',
#    'album': 'The Young and The Hopeless',
#    'release_date': '2002-10-04',
#    'track_url': 'https://open.spotify.com/track/0BRHnOFm6sjxN1i9LJrUDu',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 23,
#    'track': 'All The Small Things',
#    'artists': 'blink-182',
#    'album': 'Enema Of The State',
#    'release_date': '1999-06-01',
#    'track_url': 'https://open.spotify.com/track/2m1hi0nfMR9vdGC8UcrnwU',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 24,
#    'track': '彩虹',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/4KJx4IOvCU2isprmXio9Xk',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 25,
#    'track': 'Walking Disaster',
#    'artists': 'Sum 41',
#    'album': 'Underclass Hero',
#    'release_date': '2007-01-01',
#    'track_url': 'https://open.spotify.com/track/7xuhVUJmBpHR276Yc7AsgW',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 26,
#    'track': 'Ocean Avenue',
#    'artists': 'Yellowcard',
#    'album': 'Ocean Avenue',
#    'release_date': '2003-01-01',
#    'track_url': 'https://open.spotify.com/track/23oxJmDc1V9uLUSmN2LIvx',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 27,
#    'track': 'DARE',
#    'artists': 'Gorillaz',
#    'album': 'Demon Days',
#    'release_date': '2005-05-23',
#    'track_url': 'https://open.spotify.com/track/4Hff1IjRbLGeLgFgxvHflk',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 28,
#    'track': '千里之外',
#    'artists': 'Jay Chou',
#    'album': '依然范特西',
#    'release_date': '2006-09-05',
#    'track_url': 'https://open.spotify.com/track/02K5L2D21TVIINipDIPEfA',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 29,
#    'track': '晴天',
#    'artists': 'Jay Chou',
#    'album': '葉惠美',
#    'release_date': '2003-07-31',
#    'track_url': 'https://open.spotify.com/track/0F02KChKwbcQ3tk4q1YxLH',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 30,
#    'track': 'Stay Together For The Kids',
#    'artists': 'blink-182',
#    'album': 'Greatest Hits',
#    'release_date': '2005-10-31',
#    'track_url': 'https://open.spotify.com/track/5yRkOJ2PnUgAPlOf3FTOs2',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 31,
#    'track': 'First Date',
#    'artists': 'blink-182',
#    'album': 'Take Off Your Pants And Jacket',
#    'release_date': '2001',
#    'track_url': 'https://open.spotify.com/track/1fJFuvU2ldmeAm5nFIHcPP',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 32,
#    'track': '說好不哭',
#    'artists': 'Jay Chou; 阿信',
#    'album': '說好不哭',
#    'release_date': '2019-09-16',
#    'track_url': 'https://open.spotify.com/track/56wVfJKtnwlSZtC4NVgIrf',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 33,
#    'track': 'Teenagers',
#    'artists': 'My Chemical Romance',
#    'album': 'The Black Parade',
#    'release_date': '2006-10-23',
#    'track_url': 'https://open.spotify.com/track/7j31rVgGX9Q2blT92VBEA0',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 34,
#    'track': '開不了口',
#    'artists': 'Jay Chou',
#    'album': '范特西',
#    'release_date': '2001-09-14',
#    'track_url': 'https://open.spotify.com/track/0JB2nnrP35zVYnQcYpAnCb',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 35,
#    'track': 'After Midnight',
#    'artists': 'blink-182',
#    'album': 'Neighborhoods (Deluxe Explicit Version)',
#    'release_date': '2011-01-01',
#    'track_url': 'https://open.spotify.com/track/29bWDkf8qtCmsvDWOW55CJ',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 36,
#    'track': '浪漫手機',
#    'artists': 'Jay Chou',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/4ofmSKnAYj295dE0klRGQx',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 37,
#    'track': 'Only One',
#    'artists': 'Yellowcard',
#    'album': 'Ocean Avenue',
#    'release_date': '2003-01-01',
#    'track_url': 'https://open.spotify.com/track/0gZp88SA5OcujHLDGkxtI3',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 38,
#    'track': 'High School Never Ends - Main Version - Explicit',
#    'artists': 'Bowling For Soup',
#    'album': 'The Great Burrito Extortion Case',
#    'release_date': '2006',
#    'track_url': 'https://open.spotify.com/track/1bhjMY5O0ZjB41OHcdRH0a',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 39,
#    'track': '不能說的秘密',
#    'artists': 'Jay Chou',
#    'album': '不能說的‧秘密',
#    'release_date': '2007-08-10',
#    'track_url': 'https://open.spotify.com/track/5mktG3zst5SVxAiVHY4j6C',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 40,
#    'track': '小幸運',
#    'artists': 'Hebe Tien',
#    'album': '小幸運',
#    'release_date': '2015-07-10',
#    'track_url': 'https://open.spotify.com/track/1ZeVIrCWzEmsJexkrgvjFv',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 41,
#    'track': 'Chasing Cars',
#    'artists': 'Snow Patrol',
#    'album': 'Eyes Open',
#    'release_date': '2006-01-01',
#    'track_url': 'https://open.spotify.com/track/11bD1JtSjlIgKgZG2134DZ',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 42,
#    'track': '髮如雪',
#    'artists': 'Jay Chou',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/1jEAOrekJF0h2Rvf6mpCLd',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 43,
#    'track': '七里香',
#    'artists': 'Jay Chou',
#    'album': '七里香',
#    'release_date': '2004-08-03',
#    'track_url': 'https://open.spotify.com/track/3kwqNLXvsjSrIXbVsRBj8q',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 44,
#    'track': 'Fat Lip',
#    'artists': 'Sum 41',
#    'album': 'All Killer, No Filler',
#    'release_date': '2001-01-01',
#    'track_url': 'https://open.spotify.com/track/4KacUpvbA3Mfo05gttTjhN',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 45,
#    'track': '一路向北',
#    'artists': 'Jay Chou',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/31RIphTQ9y4zStkH5xRWgW',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 46,
#    'track': '聽見下雨的聲音',
#    'artists': 'Jay Chou',
#    'album': '哎呦 不錯哦',
#    'release_date': '2014-12-26',
#    'track_url': 'https://open.spotify.com/track/0nt1LAZjaTjrf30S8hdRDU',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 47,
#    'track': "The Man Who Can't Be Moved",
#    'artists': 'The Script',
#    'album': 'The Script',
#    'release_date': '2008-07-14',
#    'track_url': 'https://open.spotify.com/track/3nqqDo8CcCLke3ZoTgiOKf',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 48,
#    'track': '菊花台',
#    'artists': 'Jay Chou',
#    'album': '依然范特西',
#    'release_date': '2006-09-05',
#    'track_url': 'https://open.spotify.com/track/4sLlPACKA3OTNcJryGgWKR',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 49,
#    'track': '說好的幸福呢',
#    'artists': 'Jay Chou',
#    'album': '魔杰座',
#    'release_date': '2008-11-09',
#    'track_url': 'https://open.spotify.com/track/6W2tmkeuHKaedHhdTPnyVs',
#    'timeframe': 'Medium'},
#   {'user_id': 12120382831,
#    'rank': 50,
#    'track': "Adam's Song",
#    'artists': 'blink-182',
#    'album': 'Greatest Hits',
#    'release_date': '2005-10-31',
#    'track_url': 'https://open.spotify.com/track/0LQwVfQUBrWuTX19hzSJwC',
#    'timeframe': 'Medium'}],
#  'Long': [{'user_id': 12120382831,
#    'rank': 1,
#    'track': 'Crew (feat. Brent Faiyaz & Shy Glizzy)',
#    'artists': 'GoldLink; Brent Faiyaz; Shy Glizzy',
#    'album': 'At What Cost',
#    'release_date': '2017-03-24',
#    'track_url': 'https://open.spotify.com/track/15EPc80XuFrb2LmOzGjuRg',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 2,
#    'track': 'A$AP Forever REMIX (feat. Moby, T.I. & Kid Cudi)',
#    'artists': 'A$AP Rocky; Moby; T.I.; Kid Cudi',
#    'album': 'TESTING',
#    'release_date': '2018-05-25',
#    'track_url': 'https://open.spotify.com/track/3oHkMCVJyOcjg5FhfLc2Rq',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 3,
#    'track': '晴天',
#    'artists': 'Jay Chou',
#    'album': '葉惠美',
#    'release_date': '2003-07-31',
#    'track_url': 'https://open.spotify.com/track/0F02KChKwbcQ3tk4q1YxLH',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 4,
#    'track': 'pick up the phone',
#    'artists': 'Young Thug; Travis Scott',
#    'album': 'Birds In The Trap Sing McKnight',
#    'release_date': '2016-09-16',
#    'track_url': 'https://open.spotify.com/track/20dP2DaMHIAmwWAbp7peSr',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 5,
#    'track': 'Fight Night',
#    'artists': 'Migos',
#    'album': 'No Label II',
#    'release_date': '2014-06-03',
#    'track_url': 'https://open.spotify.com/track/2n5gVJ9fzeX2SSWlLQuyS9',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 6,
#    'track': 'RNP (feat. Anderson .Paak)',
#    'artists': 'Cordae; Anderson .Paak',
#    'album': 'The Lost Boy',
#    'release_date': '2019-07-26',
#    'track_url': 'https://open.spotify.com/track/5lw8Mgb4LyhriPIC86gV6e',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 7,
#    'track': 'Slide (feat. Frank Ocean & Migos)',
#    'artists': 'Calvin Harris; Frank Ocean; Migos',
#    'album': 'Slide (feat. Frank Ocean & Migos)',
#    'release_date': '2017-02-24',
#    'track_url': 'https://open.spotify.com/track/6gpcs5eMhJwax4mIfKDYQk',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 8,
#    'track': 'OKRA',
#    'artists': 'Tyler, The Creator',
#    'album': 'OKRA',
#    'release_date': '2018-03-30',
#    'track_url': 'https://open.spotify.com/track/74ZovzRxHBvCq5yIwe8boh',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 9,
#    'track': 'Icha Gicha (feat. Pharrell Williams)',
#    'artists': 'Kap G; Pharrell Williams',
#    'album': 'SupaJefe',
#    'release_date': '2017-04-14',
#    'track_url': 'https://open.spotify.com/track/5z24Bwwfp6xtCh7sSvCOJi',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 10,
#    'track': '珊瑚海',
#    'artists': 'Jay Chou; Lara Liang',
#    'album': '11月的蕭邦',
#    'release_date': '2005-11-01',
#    'track_url': 'https://open.spotify.com/track/4JY5s40ymnG18f6wxQtzPw',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 11,
#    'track': 'SICKO MODE',
#    'artists': 'Travis Scott',
#    'album': 'ASTROWORLD',
#    'release_date': '2018-08-03',
#    'track_url': 'https://open.spotify.com/track/2xLMifQCjDGFmkHkpNLD9h',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 12,
#    'track': 'Powerglide (feat. Juicy J) - From SR3MM',
#    'artists': 'Rae Sremmurd; Swae Lee; Slim Jxmmi; Juicy J',
#    'album': 'SR3MM',
#    'release_date': '2018-05-04',
#    'track_url': 'https://open.spotify.com/track/1BuZAIO8WZpavWVbbq3Lci',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 13,
#    'track': 'Sundress',
#    'artists': 'A$AP Rocky',
#    'album': 'Sundress',
#    'release_date': '2018-11-20',
#    'track_url': 'https://open.spotify.com/track/2aPTvyE09vUCRwVvj0I8WK',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 14,
#    'track': 'Takeaway (feat. Lennon Stella)',
#    'artists': 'The Chainsmokers; ILLENIUM; Lennon Stella',
#    'album': 'World War Joy...Takeaway',
#    'release_date': '2019-07-24',
#    'track_url': 'https://open.spotify.com/track/6wo37KVqFJhtuxPTpLCcfe',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 15,
#    'track': 'Plain Jane',
#    'artists': 'A$AP Ferg',
#    'album': 'Still Striving',
#    'release_date': '2017-08-18',
#    'track_url': 'https://open.spotify.com/track/4dVpf9jZjcORqGTLUaeYj9',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 16,
#    'track': 'The Blanguage',
#    'artists': 'Young Thug; Metro Boomin',
#    'album': 'Street Is Watching (The Mix-Tape)',
#    'release_date': '2014',
#    'track_url': 'https://open.spotify.com/track/1E6elLT25P95eXVMshcXZq',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 17,
#    'track': 'This Is America',
#    'artists': 'Childish Gambino',
#    'album': 'This Is America',
#    'release_date': '2018-05-06',
#    'track_url': 'https://open.spotify.com/track/0b9oOr2ZgvyQu88wzixux9',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 18,
#    'track': 'X (feat. Future)',
#    'artists': '21 Savage; Metro Boomin; Future',
#    'album': 'Savage Mode',
#    'release_date': '2016-07-15',
#    'track_url': 'https://open.spotify.com/track/6fwdbPMwP1zVStm8FybmkO',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 19,
#    'track': 'Havana (feat. Young Thug)',
#    'artists': 'Camila Cabello; Young Thug',
#    'album': 'Camila',
#    'release_date': '2018-01-12',
#    'track_url': 'https://open.spotify.com/track/1rfofaqEpACxVEHIZBJe6W',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 20,
#    'track': 'Shelter',
#    'artists': 'Porter Robinson; Madeon',
#    'album': 'Shelter',
#    'release_date': '2016-08-12',
#    'track_url': 'https://open.spotify.com/track/2CgOd0Lj5MuvOqzqdaAXtS',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 21,
#    'track': 'Potato Salad',
#    'artists': 'Tyler, The Creator; A$AP Rocky',
#    'album': 'Potato Salad',
#    'release_date': '2018-09-28',
#    'track_url': 'https://open.spotify.com/track/1jzIJcHCXneHw7ojC6LXiF',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 22,
#    'track': 'Juicy - 2005 Remaster',
#    'artists': 'The Notorious B.I.G.',
#    'album': 'Ready to Die (The Remaster)',
#    'release_date': '1994-09-13',
#    'track_url': 'https://open.spotify.com/track/5ByAIlEEnxYdvpnezg7HTX',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 23,
#    'track': 'lit(var)',
#    'artists': 'Kensuke Ushio',
#    'album': 'A Shape of Light "A Silent Voice the Movie" Original Soundtrack',
#    'release_date': '2016-09-14',
#    'track_url': 'https://open.spotify.com/track/6bTCdqB1PN5J93hiiZvQzW',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 24,
#    'track': 'I Love It (& Lil Pump)',
#    'artists': 'Kanye West; Lil Pump',
#    'album': 'I Love It',
#    'release_date': '2018-09-07',
#    'track_url': 'https://open.spotify.com/track/4S8d14HvHb70ImctNgVzQQ',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 25,
#    'track': 'Wyclef Jean',
#    'artists': 'Young Thug',
#    'album': 'JEFFERY',
#    'release_date': '2016-08-26',
#    'track_url': 'https://open.spotify.com/track/55OdqrG8WLmsYyY1jijD9b',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 26,
#    'track': '說好的幸福呢',
#    'artists': 'Jay Chou',
#    'album': '魔杰座',
#    'release_date': '2008-11-09',
#    'track_url': 'https://open.spotify.com/track/6W2tmkeuHKaedHhdTPnyVs',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 27,
#    'track': 'Unforgettable',
#    'artists': 'French Montana; Swae Lee',
#    'album': 'Jungle Rules',
#    'release_date': '2017-07-14',
#    'track_url': 'https://open.spotify.com/track/3B54sVLJ402zGa6Xm4YGNe',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 28,
#    'track': 'Fakin It (feat. Ofelia K)',
#    'artists': 'Kaskade; Felix Cartal; Ofelia K',
#    'album': 'Fakin It (feat. Ofelia K)',
#    'release_date': '2016-05-20',
#    'track_url': 'https://open.spotify.com/track/02r2uE8nEHpJAvFFttQxqh',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 29,
#    'track': 'Light',
#    'artists': 'San Holo',
#    'album': 'Light',
#    'release_date': '2017-02-10',
#    'track_url': 'https://open.spotify.com/track/6jq6rcOikCZAmjliAgAmfT',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 30,
#    'track': "Hold On, We're Going Home",
#    'artists': 'Drake; Majid Jordan',
#    'album': 'Nothing Was The Same (Deluxe)',
#    'release_date': '2013-01-01',
#    'track_url': 'https://open.spotify.com/track/6jdOi5U5LBzQrc4c1VT983',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 31,
#    'track': '彩虹',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/4KJx4IOvCU2isprmXio9Xk',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 32,
#    'track': 'Ghost Town',
#    'artists': 'Kanye West; PARTYNEXTDOOR',
#    'album': 'ye',
#    'release_date': '2018-06-01',
#    'track_url': 'https://open.spotify.com/track/6Bg7MznA9X0dIhlAsLyBYj',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 33,
#    'track': 'Mona Lisa (feat. Kendrick Lamar)',
#    'artists': 'Lil Wayne; Kendrick Lamar',
#    'album': 'Tha Carter V',
#    'release_date': '2018-09-28',
#    'track_url': 'https://open.spotify.com/track/0dbTQYW3Ad1FTzIA9t90E8',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 34,
#    'track': 'Tints (feat. Kendrick Lamar)',
#    'artists': 'Anderson .Paak; Kendrick Lamar',
#    'album': 'Tints (feat. Kendrick Lamar)',
#    'release_date': '2018-10-04',
#    'track_url': 'https://open.spotify.com/track/1gnwGVoG7V08vMX3hyr90x',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 35,
#    'track': 'Ric Flair Drip (& Metro Boomin)',
#    'artists': 'Offset; Metro Boomin',
#    'album': 'Without Warning',
#    'release_date': '2017-10-30',
#    'track_url': 'https://open.spotify.com/track/7sO5G9EABYOXQKNPNiE9NR',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 36,
#    'track': 'Sky Walker (feat. Travis Scott)',
#    'artists': 'Miguel; Travis Scott',
#    'album': 'War & Leisure',
#    'release_date': '2017-12-01',
#    'track_url': 'https://open.spotify.com/track/5WoaF1B5XIEnWfmb5NZikf',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 37,
#    'track': 'Biking',
#    'artists': 'Frank Ocean; JAY-Z; Tyler, The Creator',
#    'album': 'Biking',
#    'release_date': '2017-04-10',
#    'track_url': 'https://open.spotify.com/track/2q0VexHJirnUPnEOhr2DxK',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 38,
#    'track': 'Touch',
#    'artists': '3LAU; Carly Paige',
#    'album': 'Ultraviolet',
#    'release_date': '2018-02-16',
#    'track_url': 'https://open.spotify.com/track/5JKU2tXiG3yvJtefNwe7ZQ',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 39,
#    'track': "I Know There's Gonna Be (Good Times)",
#    'artists': 'Jamie xx; Young Thug; Popcaan',
#    'album': 'In Colour',
#    'release_date': '2015-06-01',
#    'track_url': 'https://open.spotify.com/track/6393Du1axGG1NvAMq0OcfU',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 40,
#    'track': 'Jump (feat. Gizzle)',
#    'artists': 'Lupe Fiasco; Gizzle',
#    'album': 'DROGAS Light',
#    'release_date': '2017-02-10',
#    'track_url': 'https://open.spotify.com/track/51gbF0SxTmxgAguiWWUXPu',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 41,
#    'track': 'Sweet',
#    'artists': 'Cigarettes After Sex',
#    'album': 'Cigarettes After Sex',
#    'release_date': '2017-06-09',
#    'track_url': 'https://open.spotify.com/track/2T6SuvI5GJXbJOCM1jweuW',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 42,
#    'track': 'Reverie',
#    'artists': 'ILLENIUM; King Deco',
#    'album': 'Ashes',
#    'release_date': '2016-02-15',
#    'track_url': 'https://open.spotify.com/track/46RvocxUkMUhCtDxk1BUyT',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 43,
#    'track': '蒲公英的約定',
#    'artists': 'Jay Chou',
#    'album': '我很忙',
#    'release_date': '2008-03-10',
#    'track_url': 'https://open.spotify.com/track/4hYHaROtjB6YREh6AgW3fd',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 44,
#    'track': "Don't Don't Do It!",
#    'artists': 'N.E.R.D; Kendrick Lamar; Pharrell Williams',
#    'album': 'NO ONE EVER REALLY DIES',
#    'release_date': '2017-12-15',
#    'track_url': 'https://open.spotify.com/track/2svutFGaCycRmYc1mWbfQh',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 45,
#    'track': 'Really Doe',
#    'artists': 'Danny Brown; Kendrick Lamar; Ab-Soul; Earl Sweatshirt',
#    'album': 'Atrocity Exhibition',
#    'release_date': '2016-09-27',
#    'track_url': 'https://open.spotify.com/track/6dHatCnuOb1TdBIeJTK3Y0',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 46,
#    'track': 'Sober',
#    'artists': 'Childish Gambino',
#    'album': 'Kauai',
#    'release_date': '2014-10-03',
#    'track_url': 'https://open.spotify.com/track/0PwKsFzNiOTnAus6fj7zJn',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 47,
#    'track': 'I Might Need Security',
#    'artists': 'Chance the Rapper',
#    'album': 'I Might Need Security',
#    'release_date': '2018-07-19',
#    'track_url': 'https://open.spotify.com/track/3EApebexZ7YqDIqw2EMTDh',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 48,
#    'track': 'A$AP Forever (feat. Moby)',
#    'artists': 'A$AP Rocky; Moby',
#    'album': 'A$AP Forever (feat. Moby)',
#    'release_date': '2018-04-05',
#    'track_url': 'https://open.spotify.com/track/1YmF9PvLhIISIANoMLIYGq',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 49,
#    'track': 'Old Town Road (feat. Billy Ray Cyrus) - Remix',
#    'artists': 'Lil Nas X; Billy Ray Cyrus',
#    'album': 'Old Town Road',
#    'release_date': '2019-04-05',
#    'track_url': 'https://open.spotify.com/track/6u7jPi22kF8CTQ3rb9DHE7',
#    'timeframe': 'Long'},
#   {'user_id': 12120382831,
#    'rank': 50,
#    'track': 'Old Town Road - Remix',
#    'artists': 'Lil Nas X; Billy Ray Cyrus; Mason Ramsey; Young Thug',
#    'album': 'Old Town Road (Remix)',
#    'release_date': '2019-07-12',
#    'track_url': 'https://open.spotify.com/track/6jmZlyf9DxcIoRrjw02YXm',
#    'timeframe': 'Long'}]}
